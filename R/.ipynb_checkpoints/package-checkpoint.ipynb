# %%
library(devtools)
# Out:
# Loading required package: usethis

# %%
use_git()
# Out:
# ✔ Setting active project to "/Users/xiezhihao/Documents/UBC/524/individual_assignment_R/regexcite".

# %%
(x <- "alfa,bravo,charlie,delta")
# Out:
# [1] "alfa,bravo,charlie,delta"

# %%
strsplit(x, split = ",")
# Out:
# [[1]]
# [1] "alfa"    "bravo"   "charlie" "delta"

# %%
strsplit0 <- function(x, split) {
  strsplit(x, split = split)[[1]]
}

# %%
use_r("strsplit1")
# Out:
# ☐ Edit R/strsplit1.R.

# %%
load_all()
# Out:
# ℹ Loading regexcite

# %%
strsplit1(x, split = ",")
# Out:
# [1] "alfa"    "bravo"   "charlie" "delta"

# %%
check()
# Out:
# ══ Documenting ═══════════════════════════════════════════════════════════════════════════════════════════════════════════
# ℹ Updating regexcite documentation
# ℹ Loading regexcite
# ══ Building ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
# Setting env vars:
# • CFLAGS    : -Wall -pedantic -fdiagnostics-color=always
# • CXXFLAGS  : -Wall -pedantic -fdiagnostics-color=always
# • CXX11FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX14FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX17FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX20FLAGS: -Wall -pedantic -fdiagnostics-color=always
# ── R CMD build ───────────────────────────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/Users/xiezhihao/Documents/UBC/524/individual_assignment_R/regexcite/DESCRIPTION’ (603ms)
# ─  preparing ‘regexcite’:
# ✔  checking DESCRIPTION meta-information
# ...

# %%
use_mit_license()
# Out:
# ✔ Adding "MIT + file LICENSE" to License.
#
# ✔ Writing LICENSE.
#
# ✔ Writing LICENSE.md.
#
# ✔ Adding "^LICENSE\\.md$" to .Rbuildignore.

# %%
document()
# Out:
# ℹ Updating regexcite documentation
# ℹ Loading regexcite
# Writing NAMESPACE
# Writing strsplit1.Rd

# %%
?strsplit1
# Out:
# ℹ Rendering development documentation for "strsplit1"
# regexcite:strsplit1.Rd
#
# strsplit1              package:regexcite               R Documentation
#
# g
#
# n:
#
#      Split a string
#
# e:
#
#      strsplit1(x, split)
#
# s:
#
#        x: A character vector with one element.
#
#    split: What to split on.
#
# e:
#
#      A character vector.
#
# s:
#
#      x <- "alfa,bravo,charlie,delta"
#      strsplit1(x, split = ",")

# %%
check()
# Out:
# ══ Documenting ═══════════════════════════════════════════════════════════════════════════════════════════════════════════
# ℹ Updating regexcite documentation
# ℹ Loading regexcite
# ══ Building ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
# Setting env vars:
# • CFLAGS    : -Wall -pedantic -fdiagnostics-color=always
# • CXXFLAGS  : -Wall -pedantic -fdiagnostics-color=always
# • CXX11FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX14FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX17FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX20FLAGS: -Wall -pedantic -fdiagnostics-color=always
# ── R CMD build ───────────────────────────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/Users/xiezhihao/Documents/UBC/524/individual_assignment_R/regexcite/DESCRIPTION’ (697ms)
# ─  preparing ‘regexcite’:
# ✔  checking DESCRIPTION meta-information
# ...

# %%
install()
# Out:
# ── R CMD build ───────────────────────────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/Users/xiezhihao/Documents/UBC/524/individual_assignment_R/regexcite/DESCRIPTION’ (989ms)
# ─  preparing ‘regexcite’:
# ✔  checking DESCRIPTION meta-information
# ─  excluding invalid files (784ms)
#    Subdirectory 'R' contains invalid file names:
#      ‘package.ipynb’
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘regexcite_0.0.0.9000.tar.gz’
#
# Running /Library/Frameworks/R.framework/Resources/bin/R CMD INSTALL \
#   /var/folders/w7/f10d_sld2w180vyy3zmm8nj00000gn/T//RtmpMkZUuI/regexcite_0.0.0.9000.tar.gz \
#   --install-tests
# * installing to library ‘/Library/Frameworks/R.framework/Versions/4.5-x86_64/Resources/library’
# * installing *source* package ‘regexcite’ ...
# ** this is package ‘regexcite’ version ‘0.0.0.9000’
# ...

# %%
use_testthat()
# Out:
# ✔ Adding testthat to Suggests field in DESCRIPTION.
#
# ✔ Adding "3" to Config/testthat/edition.
#
# ✔ Creating tests/testthat/.
#
# ✔ Writing tests/testthat.R.
#
# ☐ Call `usethis::use_test()` to initialize a basic test file and open it for editing.

# %%
use_test("strsplit1")
# Out:
# ✔ Writing tests/testthat/test-strsplit1.R.
#
# ☐ Edit tests/testthat/test-strsplit1.R.

# %%
test()
# Out:
# ℹ Testing regexcite
#
# Attaching package: ‘testthat’
#
#
# The following object is masked from ‘package:devtools’:
#
#     test_file
# ✔ | F W  S  OK | Context
# ✔ |          1 | strsplit1
#
# ══ Results ═══════════════════════════════════════════════════════════════════════════════════════════════════════════════
# [ FAIL 0 | WARN 0 | SKIP 0 | PASS 1 ]
